# %%
import pandas as pd
import numpy as np


print("FinTech Analytics Project Started")
# Out:
# FinTech Analytics Project Started

# %% [markdown]
# # FinTech Loan Risk & Customer Analytics
#
# ## Day 1 — Project Initialization
#
# This notebook initializes the fintech analytics project environment.
