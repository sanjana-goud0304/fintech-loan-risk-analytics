# %% [markdown]
# ## Dashboard Insight
#
# Salaried and middle-income customers represent the majority of the active loan portfolio.

# %% [markdown]
# ## Risk Insight
#
# Missed payments are significantly associated with higher-risk loan accounts.
