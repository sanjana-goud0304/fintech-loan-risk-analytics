# %% [markdown]
# # Day 4 — SQL Data Loading & Analytics
#
# ## Objective
# Load fintech datasets into MySQL and run business analytics queries.
#
# ## Concepts Learned
# - Database Import
# - SQL Queries
# - JOINs
# - Aggregation
# - Risk Analysis
