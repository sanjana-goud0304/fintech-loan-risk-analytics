# %% [markdown]
# # Day 2 — Database Design
#
# ## Objective
# Design a real-world fintech database schema for:
# - customers
# - loans
# - transactions
# - repayments
# - credit scores
#
# ## Concepts Learned
# - Primary Keys
# - Foreign Keys
# - One-to-Many Relationships
# - Entity Relationship Design
